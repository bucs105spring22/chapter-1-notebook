# %% [markdown]
# # Introduction to Computers

# %% [markdown]
# ## Chapter 1: Computer Basics

# %% [markdown]
# * Accepts input
# * process input
# * output
# * repeat a set of selected instructions
#
# The only difference between computers is time and memory

# %% [markdown]
# ## What does a computer actually do?

# %% [markdown]
# Computers are dumb
#
# Everything a computer does is an instruction gvien to it by a human

# %% [markdown]
# # Computer Data

# %% [markdown]
# All computer data is ultimately a 1 or a 0

# %%
print("hello")
# Out:
# hello

# %% [markdown]
# Binary - base 2
# Decimal - base 10
#
# 1 - High voltage
# 0 - Low voltage
#
# Digital System  - any system that is not infinite

# %% [markdown]
# ## ASCII
#
# Every character is stored as an 8 bit value
# * 8 1 and 0's in a character
#
# p = 01110000
# P = 01010000
# 1 = 00110001

# %% [markdown]
# ## Sort a deck of Cards
#
# * Algorithm
#     * All algorithms are a tradeoff between time it take and memory
# * Assumptions
#     * Speaking Language
#     * Type of Cards
#     * Ace
#     * Suits or values
# * Efficiency
#     * number of steps
#     * time
#     * memory usage
#     * How easy your algorithm is to understand
# * Verify
#     * go through deck at least twice to verify

# %% [markdown]
# ### Computer Hardware

# %% [markdown]
# Alan Turing - Mathematician

# %% [markdown]
# Turing Machine
#
# Machine that takes input, performs a single operation, and produces output

# %% [markdown]
# **Universal Turing Machine**

# %% [markdown]
# Inputs => operations => output
#
# inputs and operation => perform operation on inputs => output
#
# Programmable: Give it multiple types of operations

# %% [markdown]
# As size and cost decreased, speed and quality increased
#
#
# The got cheap enough, fast enough, easy enough to use for consumers

# %% [markdown]
# Input - Mouse, Keyboard, Files on your computers (network files)
# Processing - CPU, Memory (RAM), Motherboard, GPU
# Output - Monitor, Printers
# Storage - Where output is saved for later

# %% [markdown]
# ### Operating Systems
#
# 1. Power on
# 2. BIOS - Micro-OS to bootstrap or initialize the hardware and select the OS
# 3. OS - Loaded into RAM (or memory)
# 4. GUI Displayed
# 5. User interacts
# 6. OS loads user selected programs and preferences

# %% [markdown]
# ##### Files
#
# OS's manage files
#
# Types - Files types
#
# Two pieces of information about data
# * The data itself
# * the type of the data
#
#
# # File Types
#
# * Binary - you need to know the type
# * Text - formatting

# %% [markdown]
# ##### Directories
#
# * Folders that contains files or other folders
#
# * Top level directory - ROOT
#     * C:/ - Windows
#     * / - Mac and Unix
